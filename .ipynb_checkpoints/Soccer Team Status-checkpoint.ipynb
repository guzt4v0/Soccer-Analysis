# %%
import pandas as pd

# %%
df = pd.read_csv("data/2021-2022-Football-Team-Stats.csv", encoding="latin-1", sep=";")

# %% [markdown]
# https://www.kaggle.com/datasets/vivovinco/20212022-football-team-stats

# %%
df.head(6)
# Out:
#    Rk            Squad Country  LgRk  MP   W  D  L  GF  GA  ...  Pts  Pts/G  \
# 0   1  Manchester City     ENG     1  37  28  6  3  96  24  ...   90   2.43
# 1   2        Liverpool     ENG     2  36  26  8  2  89  24  ...   86   2.39
# 2   3      Real Madrid     ESP     1  37  26  7  4  80  31  ...   85   2.30
# 3   4    Bayern Munich     GER     1  34  24  5  5  97  37  ...   77   2.26
# 4   5        Paris S-G     FRA     1  37  25  8  4  85  36  ...   83   2.24
# 5   6            Milan     ITA     1  37  25  8  4  66  31  ...   83   2.24
#
#      xG   xGA   xGD  xGD/90     Last 5 Attendance          Top Team Scorer  \
# 0  86.1  26.8  59.3    1.60  W W W W D      52739     Kevin De Bruyne - 15
# 1  84.6  33.1  51.4    1.43  W W W D W      53367       Mohamed Salah - 22
# 2  73.0  45.8  27.2    0.73  W W L W D      40624       Karim Benzema - 27
# 3  88.1  37.1  51.0    1.50  W W L D D      33176  Robert Lewandowski - 35
# ...

# %%
df.describe()
# Out:
#               Rk       LgRk         MP          W          D         L  \
# count  98.000000  98.000000  98.000000  98.000000  98.000000  98.00000
# mean   49.500000  10.316327  36.306122  13.448980   9.408163  13.44898
# std    28.434134   5.706926   1.152390   5.747474   2.903381   5.12347
# min     1.000000   1.000000  34.000000   3.000000   3.000000   2.00000
# 25%    25.250000   5.250000  36.000000   9.000000   7.000000  10.00000
# 50%    49.500000  10.000000  37.000000  13.000000   9.000000  13.00000
# 75%    73.750000  15.000000  37.000000  17.000000  11.000000  17.00000
# max    98.000000  20.000000  37.000000  28.000000  16.000000  26.00000
#
#               GF         GA         GD        Pts      Pts/G         xG  \
# count  98.000000  98.000000  98.000000  98.000000  98.000000  98.000000
# mean   50.877551  50.877551   0.000000  49.734694   1.370204  48.653061
# std    16.102933  13.634602  26.501896  16.166371   0.443903  12.453950
# ...

# %%
df.columns
# Out:
# Index(['Rk', 'Squad', 'Country', 'LgRk', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD',
#        'Pts', 'Pts/G', 'xG', 'xGA', 'xGD', 'xGD/90', 'Last 5', 'Attendance',
#        'Top Team Scorer', 'Goalkeeper'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Rk                   int64
# Squad               object
# Country             object
# LgRk                 int64
# MP                   int64
# W                    int64
# D                    int64
# L                    int64
# GF                   int64
# GA                   int64
# GD                   int64
# Pts                  int64
# Pts/G              float64
# xG                 float64
# xGA                float64
# xGD                float64
# xGD/90             float64
# Last 5              object
# Attendance           int64
# Top Team Scorer     object
# Goalkeeper          object
# dtype: object

# %%
df = df.drop(columns=['Rk','Pts/G','xG', 'xGA', 'xGD', 'xGD/90', 'Last 5'])

# %%
df.head(6)
# Out:
#              Squad Country  LgRk  MP   W  D  L  GF  GA  GD  Pts  Attendance  \
# 0  Manchester City     ENG     1  37  28  6  3  96  24  72   90       52739
# 1        Liverpool     ENG     2  36  26  8  2  89  24  65   86       53367
# 2      Real Madrid     ESP     1  37  26  7  4  80  31  49   85       40624
# 3    Bayern Munich     GER     1  34  24  5  5  97  37  60   77       33176
# 4        Paris S-G     FRA     1  37  25  8  4  85  36  49   83       41188
# 5            Milan     ITA     1  37  25  8  4  66  31  35   83       42388
#
#            Top Team Scorer        Goalkeeper
# 0     Kevin De Bruyne - 15           Ederson
# 1       Mohamed Salah - 22           Alisson
# 2       Karim Benzema - 27  Thibaut Courtois
# 3  Robert Lewandowski - 35      Manuel Neuer
# 4       Kylian Mbappé - 25      Keylor Navas
# 5         Rafael Leão - 11      Mike Maignan

# %%
df[['Top Team Scorer Player','Goals Top Player']] = df["Top Team Scorer"].str.split(" - ",expand=True,)

# %%
df.head(6)
# Out:
#              Squad Country  LgRk  MP   W  D  L  GF  GA  GD  Pts  Attendance  \
# 0  Manchester City     ENG     1  37  28  6  3  96  24  72   90       52739
# 1        Liverpool     ENG     2  36  26  8  2  89  24  65   86       53367
# 2      Real Madrid     ESP     1  37  26  7  4  80  31  49   85       40624
# 3    Bayern Munich     GER     1  34  24  5  5  97  37  60   77       33176
# 4        Paris S-G     FRA     1  37  25  8  4  85  36  49   83       41188
# 5            Milan     ITA     1  37  25  8  4  66  31  35   83       42388
#
#            Top Team Scorer        Goalkeeper Top Team Scorer Player  \
# 0     Kevin De Bruyne - 15           Ederson        Kevin De Bruyne
# 1       Mohamed Salah - 22           Alisson          Mohamed Salah
# 2       Karim Benzema - 27  Thibaut Courtois          Karim Benzema
# 3  Robert Lewandowski - 35      Manuel Neuer     Robert Lewandowski
# 4       Kylian Mbappé - 25      Keylor Navas          Kylian Mbappé
# ...

# %%
df = df.drop(columns=["Top Team Scorer"])

# %%
df.head(6)
# Out:
#              Squad Country  LgRk  MP   W  D  L  GF  GA  GD  Pts  Attendance  \
# 0  Manchester City     ENG     1  37  28  6  3  96  24  72   90       52739
# 1        Liverpool     ENG     2  36  26  8  2  89  24  65   86       53367
# 2      Real Madrid     ESP     1  37  26  7  4  80  31  49   85       40624
# 3    Bayern Munich     GER     1  34  24  5  5  97  37  60   77       33176
# 4        Paris S-G     FRA     1  37  25  8  4  85  36  49   83       41188
# 5            Milan     ITA     1  37  25  8  4  66  31  35   83       42388
#
#          Goalkeeper Top Team Scorer Player Goals Top Player
# 0           Ederson        Kevin De Bruyne               15
# 1           Alisson          Mohamed Salah               22
# 2  Thibaut Courtois          Karim Benzema               27
# 3      Manuel Neuer     Robert Lewandowski               35
# 4      Keylor Navas          Kylian Mbappé               25
# 5      Mike Maignan            Rafael Leão               11

# %%
df.dtypes
# Out:
# Squad                     object
# Country                   object
# LgRk                       int64
# MP                         int64
# W                          int64
# D                          int64
# L                          int64
# GF                         int64
# GA                         int64
# GD                         int64
# Pts                        int64
# Attendance                 int64
# Goalkeeper                object
# Top Team Scorer Player    object
# Goals Top Player          object
# dtype: object

# %%
df["Goals Top Player"] = df["Goals Top Player"].astype(str).astype('int64')

# %%
df.dtypes
# Out:
# Squad                     object
# Country                   object
# LgRk                       int64
# MP                         int64
# W                          int64
# D                          int64
# L                          int64
# GF                         int64
# GA                         int64
# GD                         int64
# Pts                        int64
# Attendance                 int64
# Goalkeeper                object
# Top Team Scorer Player    object
# Goals Top Player           int64
# dtype: object

# %%
df.describe()
# Out:
#             LgRk         MP          W          D         L         GF  \
# count  98.000000  98.000000  98.000000  98.000000  98.00000  98.000000
# mean   10.316327  36.306122  13.448980   9.408163  13.44898  50.877551
# std     5.706926   1.152390   5.747474   2.903381   5.12347  16.102933
# min     1.000000  34.000000   3.000000   3.000000   2.00000  23.000000
# 25%     5.250000  36.000000   9.000000   7.000000  10.00000  39.000000
# 50%    10.000000  37.000000  13.000000   9.000000  13.00000  47.000000
# 75%    15.000000  37.000000  17.000000  11.000000  17.00000  60.000000
# max    20.000000  37.000000  28.000000  16.000000  26.00000  97.000000
#
#               GA         GD        Pts    Attendance  Goals Top Player
# count  98.000000  98.000000  98.000000     98.000000         98.000000
# mean   50.877551   0.000000  49.734694  24239.857143         12.591837
# std    13.634602  26.501896  16.166371  14874.171842          5.514436
# ...

# %%
df.groupby(['Country'])['Attendance'].mean().round(2)
# Out:
# Country
# ENG    39538.70
# ESP    22937.60
# FRA    20314.00
# GER    21025.06
# ITA    17062.45
# Name: Attendance, dtype: float64
